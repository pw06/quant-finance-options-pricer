# %%
import sys
import importlib
from pathlib import Path
tests_path = Path.cwd().parent / "tests"
sys.path.append(str(tests_path))
import tests
importlib.reload(tests)


T = 2
t = 0.5
S0 = 100
K = 105
sigma = 0.2
r = 0.05


# Proof of convergence: Black Scholes numerical (explicit) solution -> Black Scholes analytical solution 
tests.fd_bs_conv(S0, t, T, r, K, sigma)
# Out:
# Analytical BS price: 10.969808
# FD price: 9.867022
# Absolute value of difference: 1.103 $
# Time needed for solution of numerical method: 0.00 seconds
# FD price: 10.916086
# Absolute value of difference: 0.054 $
# Time needed for solution of numerical method: 0.00 seconds
# FD price: 11.037486
# Absolute value of difference: 0.068 $
# Time needed for solution of numerical method: 0.01 seconds
# FD price: 10.969941
# Absolute value of difference: 0.000 $
# Time needed for solution of numerical method: 0.02 seconds
# FD price: 10.971830
# Absolute value of difference: 0.002 $
# Time needed for solution of numerical method: 0.06 seconds
# FD price: 10.970443
# Absolute value of difference: 0.001 $
# Time needed for solution of numerical method: 0.49 seconds
# FD price: 10.969713
# Absolute value of difference: 0.000 $
# Time needed for solution of numerical method: 5.04 seconds

# %%
import sys
import importlib
from pathlib import Path
tests_path = Path.cwd().parent / "tests"
sys.path.append(str(tests_path))
import tests
importlib.reload(tests)


T = 2
t = 0.5
S0 = 100
K = 105
sigma = 0.2
r = 0.05

# Proof of convergence: MonteCarlo -> Black Scholes analytical solution 
tests.mc_bs_conv(S0, t, T, K, r, sigma)
# Out:
# Call price via Black-Scholes: 10.97
# expected payoff: 0.00$
# Monte Carlo call price: 0.00$
# Absolute value of difference: 10.970 $
# Time needed for simulation: 0.06 seconds
# expected payoff: 4.48$
# Monte Carlo call price: 4.15$
# Absolute value of difference: 6.815 $
# Time needed for simulation: 0.06 seconds
# expected payoff: 14.01$
# Monte Carlo call price: 13.00$
# Absolute value of difference: 2.028 $
# Time needed for simulation: 0.08 seconds
# expected payoff: 11.75$
# Monte Carlo call price: 10.90$
# Absolute value of difference: 0.070 $
# Time needed for simulation: 0.37 seconds
# expected payoff: 12.10$
# Monte Carlo call price: 11.23$
# Absolute value of difference: 0.259 $
# Time needed for simulation: 1.71 seconds
# expected payoff: 11.54$
# Monte Carlo call price: 10.70$
# Absolute value of difference: 0.265 $
# Time needed for simulation: 5.46 seconds
# expected payoff: 11.87$
# Monte Carlo call price: 11.01$
# Absolute value of difference: 0.041 $
# ...

# %%
import sys
import importlib
from pathlib import Path
tests_path = Path.cwd().parent / "tests"
sys.path.append(str(tests_path))
import tests
importlib.reload(tests)


T = 2
t = 0.5
S0 = 100
K = 105
sigma = 0.2
r = 0.05

# Proof of convergence: MonteCarlo, Black Scholes numerical solution -> Black Scholes analytical solution 
tests.fd_mc_bs(S0, t, T, r, K, sigma)
# Out:
# mc: 10
# mc: 100
# mc: 1000
# mc: 5000
# mc: 10000
# mc: 15000
# mc: 25000
# mc: 50000
# fd: 10
# fd: 50
# fd: 100
# fd: 250
# fd: 500
# fd: 750
# fd: 1000
# fd: 1500
