# %%
import sys
sys.path.append("/Users/philip/quant-finance2/src")  # zeigt auf den Ordner
import monte_carlo as mc

n = 5000
S = 100
t = 0.2
T = 2
r = 0.04
sigma = 0.2
K = 105

mc.monte_carlo_func(S, t, T, K, r, sigma, n)
# Out:
# 114.2635705281581

# %%
import sys
sys.path.append("/Users/philip/quant-finance2/src")  # zeigt auf den Ordner
import importlib
import monte_carlo
import tests
import black_scholes

importlib.reload(tests)
n = 5000
S = 100
t = 0.2
T = 2
r = 0.04
sigma = 0.2
K = 105

tests.mc_bs_conv(S, t, T, K, r, sigma)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[29], line 17
#      13 r = 0.04
#      14 sigma = 0.2
#      15 K = 105
#      16
# ---> 17 tests.mc_bs_conv(S, t, T, K, r, sigma)
#
# File ~/quant-finance2/src/tests.py:10, in mc_bs_conv(S, t, T, K, r, sigma)
#       8 x = [1, 10, 100, 1000, 5000, 10000, 15000, 20000]
#       9 dif = np.zeros(len(x))
# ---> 10 ana_price = black_scholes_call(S, t, T, K, r, sigma)
#      12 for i in range(len(x)):
#      13     sim_price = monte_carlo_func(S, t, T, K ,r , sigma, x[i])
#
# File ~/quant-finance2/src/black_scholes.py:12, in black_scholes_call(S, t, T, K, r, sigma)
#      11 def black_scholes_call(S, t, T, K, r, sigma):
# ---> 12     d1 = (np.ln(S/K) + (r + (sigma**2)/(2))*(T - t))/(sigma * np.sqrt(T - t))
#      13     d2 = d1 - sigma * np.sqrt(T - t)
#      15     call_price = S * phi(d1) - K * np.exp(-r * (T - t)) * phi(d2)
# ...

# %%
import sys
sys.path.append("/Users/philip/quant-finance2/src")  # zeigt auf den Ordner
import importlib
import monte_carlo
import tests
import black_scholes
importlib.reload(black_scholes)
importlib.reload(tests)
importlib.reload(monte_carlo)

n = 5000
S = 100
t = 0.2
T = 2
r = 0.04
sigma = 0.2
K = 105

tests.mc_bs_conv(S, t, T, K, r, sigma)
# Out:
# Call price via Black-Scholes: 11.74
# 130.6846228803734
# expected payoff: 25.68$
# Monte Carlo call price: 23.90$
# Absolute value of difference: 12.163714712620536 seconds
# Time needed for simulation: 0.08
# 101.58821521460312
# expected payoff: 5.03$
# Monte Carlo call price: 4.68$
# Absolute value of difference: 7.052262671841692 seconds
# Time needed for simulation: 0.07
# 105.04458988471593
# expected payoff: 11.20$
# Monte Carlo call price: 10.42$
# Absolute value of difference: 1.3186733207580144 seconds
# Time needed for simulation: 0.11
# 108.52934274674558
# expected payoff: 13.26$
# Monte Carlo call price: 12.34$
# Absolute value of difference: 0.6020852425723078 seconds
# Time needed for simulation: 0.71
# 107.5307495196536
# expected payoff: 12.69$
# Monte Carlo call price: 11.81$
# Absolute value of difference: 0.07391714008941364 seconds
# Time needed for simulation: 3.31
# 107.26161052224562
# expected payoff: 12.48$
# Monte Carlo call price: 11.62$
# ...
