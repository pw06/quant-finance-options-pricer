# %%
import sys
import importlib
from pathlib import Path
tests_path = Path.cwd().parent / "tests"
sys.path.append(str(tests_path))
import tests
importlib.reload(tests)


T = 2
t = 0.5
S0 = 100
K = 105
sigma = 0.2
r = 0.05


# Proof of convergence: Black Scholes numerical (explicit) solution -> Black Scholes analytical solution 
tests.fd_bs_conv(S0, t, T, r, K, sigma)
# Out:
# Analytical BS price: 10.969808
# FD price: 9.867022
# Absolute value of difference: 1.103 $
# Time needed for solution of numerical method: 0.00 seconds
# FD price: 10.916086
# Absolute value of difference: 0.054 $
# Time needed for solution of numerical method: 0.00 seconds
# FD price: 11.037486
# Absolute value of difference: 0.068 $
# Time needed for solution of numerical method: 0.01 seconds
# FD price: 10.969941
# Absolute value of difference: 0.000 $
# Time needed for solution of numerical method: 0.02 seconds
# FD price: 10.971830
# Absolute value of difference: 0.002 $
# Time needed for solution of numerical method: 0.06 seconds
# FD price: 10.970443
# Absolute value of difference: 0.001 $
# Time needed for solution of numerical method: 0.44 seconds
# FD price: 10.969713
# Absolute value of difference: 0.000 $
# Time needed for solution of numerical method: 4.37 seconds

# %%
import sys
import importlib
from pathlib import Path
tests_path = Path.cwd().parent / "tests"
sys.path.append(str(tests_path))
import tests
importlib.reload(tests)


T = 2
t = 0.5
S0 = 100
K = 105
sigma = 0.2
r = 0.05

# Proof of convergence: MonteCarlo -> Black Scholes analytical solution 

tests.mc_bs_conv(S0, t, T, K, r, sigma)
# Out:
# Call price via Black-Scholes: 10.97
# expected payoff: 0.00$
# Monte Carlo call price: 0.00$
# Absolute value of difference: 10.970 $
# Time needed for simulation: 0.04 seconds
# expected payoff: 6.52$
# Monte Carlo call price: 6.05$
# Absolute value of difference: 4.921 $
# Time needed for simulation: 0.05 seconds
# expected payoff: 13.36$
# Monte Carlo call price: 12.39$
# Absolute value of difference: 1.422 $
# Time needed for simulation: 0.41 seconds
# expected payoff: 11.16$
# Monte Carlo call price: 10.35$
# Absolute value of difference: 0.617 $
# Time needed for simulation: 0.38 seconds
# expected payoff: 11.88$
# Monte Carlo call price: 11.02$
# Absolute value of difference: 0.053 $
# Time needed for simulation: 1.90 seconds
# expected payoff: 11.50$
# Monte Carlo call price: 10.67$
# Absolute value of difference: 0.302 $
# Time needed for simulation: 4.34 seconds
# expected payoff: 11.97$
# Monte Carlo call price: 11.11$
# Absolute value of difference: 0.138 $
# Time needed for simulation: 6.26 seconds
# expected payoff: 11.73$
# Monte Carlo call price: 10.89$
# Absolute value of difference: 0.084 $
# Time needed for simulation: 8.05 seconds
# expected payoff: 11.91$
# Monte Carlo call price: 11.05$
# Absolute value of difference: 0.078 $
# Time needed for simulation: 11.66 seconds
# expected payoff: 11.82$
# Monte Carlo call price: 10.97$
# Absolute value of difference: 0.003 $
# Time needed for simulation: 15.46 seconds
# expected payoff: 11.80$
# Monte Carlo call price: 10.94$
# Absolute value of difference: 0.027 $
# Time needed for simulation: 18.80 seconds
