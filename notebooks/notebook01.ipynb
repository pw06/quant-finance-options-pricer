# %%
import monte_carlo as mc
import importlib
importlib.reload(monte_carlo)

n = 5000
S = 100
t = 0.2
T = 2
r = 0.04
sigma = 0.2
K = 105

mc.monte_carlo_func(S, t, T, K, r, sigma, n)
# Out:
# expected payoff: 12.52$
# Monte Carlo call price: 11.65$
# (np.float64(12.519326054424791), np.float64(11.649619688376468))

# %%
import tests
import finite_dif
import importlib
importlib.reload(tests)
importlib.reload(finite_dif)

S = 100
t = 0.2
T = 2
r = 0.04
sigma = 0.2
K = 105

tests.fd_bs_conv(S, t, T, r, K , sigma)
# Out:
# Analytical BS price: 11.736620
# FD price: 10.691970
# Absolute value of difference: 1.045 $
# Time needed for solution of numerical method: 0.00 seconds
# FD price: 11.697110
# Absolute value of difference: 0.040 $
# Time needed for solution of numerical method: 0.00 seconds
# FD price: 11.799442
# Absolute value of difference: 0.063 $
# Time needed for solution of numerical method: 0.00 seconds
# FD price: 11.737004
# Absolute value of difference: 0.000 $
# Time needed for solution of numerical method: 0.01 seconds
# FD price: 11.738535
# Absolute value of difference: 0.002 $
# Time needed for solution of numerical method: 0.06 seconds
# FD price: 11.737212
# Absolute value of difference: 0.001 $
# Time needed for solution of numerical method: 0.53 seconds
# FD price: 11.736536
# Absolute value of difference: 0.000 $
# Time needed for solution of numerical method: 3.43 seconds
