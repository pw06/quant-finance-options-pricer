# %%
import sys
sys.path.append("/Users/philip/quant-finance2/src")  # zeigt auf den Ordner
import monte_carlo as mc

n = 5000
S = 100
t = 0.2
T = 2
r = 0.04
sigma = 0.2
K = 105

mc.monte_carlo_func(S, t, T, K, r, sigma, n)
# Out:
# 114.2635705281581

# %%
import sys
sys.path.append("/Users/philip/quant-finance2/src")  # zeigt auf den Ordner
import importlib
import monte_carlo

importlib.reload(monte_carlo)
n = 5000
S = 100
t = 0.2
T = 2
r = 0.04
sigma = 0.2
K = 105

monte_carlo.monte_carlo_func(S, t, T, K, r, sigma, n)
# Out:
# 114.07157066132855
# expected payoff: 20.62$
# Monte Carlo call price: 19.18$
# (np.float64(20.617160158065072), np.float64(19.184904510967392))
